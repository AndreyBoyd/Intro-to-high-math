# %% [markdown]
# ## Практические задания к уроку 4
#
# Инструкции к сдаче:
# Присылайте фото листочков с вашими решениями или просто ответы в текстовом файле .doc или .txt (1-3 задание).
#
#
# Прикладывайте ссылку на ваш репозиторий с кодом (4 задание). Для написания кода используйте привычную среду программирования, желательно, Jupiter Notebook
#
# ### Тема “Аналитическая геометрия” и “Графики на плоскости”
# 1. Задание (на листочке)
# Решите уравнение
# sin(x)/x=0.
#
# 2. Задание (на листочке)
# Даны три прямые y=k1*x+b1, y=k2*x+b2,, y=k3*x+b3. Как узнать, пересекаются они в одной точке или нет?
#
# 3. Задание (в программе или на листочке)
# На листе тетради «в линейку» (расстояние между линиями равно а) лежит игла (длиной b). Координаты нижней точки иглы (х,у), игла лежит под углом alfa. Пересекает ли игла линию или нет?
#
# 4. Задание** (задание делать по желанию)

# %% [markdown]
# ### 1. Задание (на листочке) Решите уравнение sin(x)/x=0.

# %% [markdown]
# #### Дано:
#
# $\cfrac{sin(x)}{x}=0$
#
# #### Решение:
#
# $ОДЗ:x\ne0 => sin(x)=0$
#
# #### Ответ:
#
# $x = \pi$

# %% [markdown]
# ### 2. Задание (на листочке) Даны три прямые y=k1x+b1, y=k2x+b2,, y=k3*x+b3. Как узнать, пересекаются они в одной точке или нет?

# %% [markdown]
# #### Дано:
#
# $
# y=k1 \cdot x+b1\\
# y=k2 \cdot x+b2\\
# y=k3 \cdot x+b3
# $
#
# #### Решение:
#
# $
# \begin{cases}
# y=k1 \cdot x+b1\\
# y=k2 \cdot x+b2\\
# y=k3 \cdot x+b3
# \end{cases}
# $
#
# Выразим x и y через k1, k2, k3, b1, b2 и b3
#
# $y = k1 \cdot x + b1$
#
# $k2 \cdot x + b2 - y = 0$
#
# Заменим y и найдём x
#
# $k2 \cdot x + b2 - (k1 \cdot x + b1) = 0$
#
# $k2 \cdot x + b2 - k1 \cdot x - b1 = 0$
#
# $k2 \cdot x - k1 \cdot x + b2 - b1 = 0$
#
# $k2 \cdot x - k1 \cdot x = b1 - b2$
#
# $x \cdot (k2 - k1) = b1 - b2$
#
# $x = \cfrac{b1 - b2}{k2 - k1}$

# %% [markdown]
# #### Ответ:
#
# $
# x = \cfrac{b1 - b2}{k2 - k1}\\
# y = k3 \cdot \cfrac{b1 - b2}{k2 - k1} + b3
# $
#
# Как узнать, пересекаются они в одной точке или нет?
#
# Найдем точку пересечения, например, первой и второй прямой и проверим лежит ли она на третьей прямой.
# Для этого, приравняем правые части и найдем х, затем найдем у. Если точка пересечения первой и второй прямой имеет координаты, то подставляем эти координаты в третье уравнение и решаем его, если уравнение имеет решение, то 3 заданные прямые пересекаются в этой точке.

# %% [markdown]
# ### 3. Задание (в программе или на листочке)
# На листе тетради «в линейку» (расстояние между линиями равно а) лежит игла (длиной b). Координаты нижней точки иглы (х,у), игла лежит под углом  𝛼 . Пересекает ли игла линию или нет?

# %% [markdown]
# #### Дано:
#
# a - расстояние между линиями
#
# b - длина иголки, является гипотенузой
#
# $\angle 𝛼$ - угол между линией и иголкой
#
# #### Решение:
#
# Для решения задачи необходимо сделать несколько допущений (иначе условия некорректны):
# 1. Точка (x,y) лежит на на прямой совпадающей с линией тетрадки. В противном случае, например, игла может быть хоть 1 метр длиной лежать между линий и быть параллельной линии тетрадки, либо с очень малым углом наклона.
# 2. Линия на которой лежит точка с координатами (x, y) не является первой или последней линией на странице. Без такого допущения, игла может быть хоть 10 метров длиной лежать перпендикулярно линнии тетради и выходить за пределы страницы не пересекая не одну линию.
# 3. Полное совпадение иглы с линией не является пересечением.
# 4. Наличие второй общей точки кроме точки (x, y) с любой другой линий является пересечением. Вариант когда игла косается соседней линии (это вопрос $\geq$, вместо просто >).
#
# Представим линию как прилежащий катет, иголку как гипотенузу и найдём противолежащий катет (обозначим его c).
#
# $c = b \cdot \sin{\alpha}$
#
# #### Ответ:
#
# Если $c \geq a$ - игла пересекает линию, в противном случае не персекает.

# %%
from IPython.display import IFrame, display

# %%
filepath = "task4.pdf"
IFrame(filepath, width=900, height=950)
# Out:
#         <iframe
#             width="900"
#             height="950"
#             src="task4.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
